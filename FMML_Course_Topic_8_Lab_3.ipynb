# %% [markdown]
# <a href="https://colab.research.google.com/github/Daliboinasatish5/Fmml-Assignments/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-30 14:58:57--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   266MB/s    in 0.3s
#
# 2024-03-30 14:58:58 (266 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 13     1604.01662v2  While perception tasks such as visual object r...  stat
# 3310   1506.02108v3  Deep structured output learning shows great pr...    cs
# 11631  1608.03585v1  We develop a framework for warm-starting Bayes...  stat
# 9443   1801.09303v1  This paper describes a general framework for l...  stat
# 2446    1402.0635v3  We propose randomized least-squares value iter...  stat
# ...             ...                                                ...   ...
# 23047  1802.07481v2  Convex sparsity-inducing regularizations are u...  stat
# 2644   1703.04730v2  How can we explain the predictions of a black-...  stat
# 25938  1512.06559v2  Retinal images provide early signs of diabetic...    cs
# 13325   1002.1176v1  This paper describes a new method for the synt...    cs
# 21552   1009.2139v4  Sparse coding consists in representing signals...  stat
#
#                                                    title  year  \
# 13              Towards Bayesian Deep Learning: A Survey  2016
# 3310   Deeply Learning the Messages in Message Passin...  2015
# 11631                Warm Starting Bayesian Optimization  2016
# 9443               HONE: Higher-Order Network Embeddings  2018
# 2446   Generalization and Exploration via Randomized ...  2014
# ...                                                  ...   ...
# 23047        Dual Extrapolation for Faster Lasso Solvers  2018
# 2644   Understanding Black-box Predictions via Influe...  2017
# 25938  Analysis of Vessel Connectivities in Retinal I...  2015
# 13325  Phase-Only Planar Antenna Array Synthesis with...  2010
# 21552    Proximal Methods for Hierarchical Sparse Coding  2010
#
#                                                 keywords
# 13     [perception, recognition, understanding, impor...
# 3310   [structured, segmentation, efficient, structur...
# 11631  [framework, optimization, optimization, optimi...
# 9443   [describes, framework, embeddings, framework, ...
# 2446   [randomized, iteration, reinforcement, algorit...
# ...                                                  ...
# 23047  [regularizations, ubiquitous, dimension, diffe...
# 2644   [predictions, influence, functions, technique,...
# 25938  [retinopathy, hypertension, investigated, micr...
# 13325  [describes, synthesis, algorithms, optimizing,...
# 21552  [representing, combinations, dictionary, exten...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 13       [perception, recognition, understanding, impor...
# 3310     [structured, segmentation, efficient, structur...
# 11631    [framework, optimization, optimization, optimi...
# 9443     [describes, framework, embeddings, framework, ...
# 2446     [randomized, iteration, reinforcement, algorit...
#                                ...
# 1977     [detection, traditional, detection, detection,...
# 9185     [performance, automatic, recognition, environm...
# 13700    [intelligent, algorithm, algorithm, principles...
# 37496    [knowledge, attributes, intuitively, attribute...
# 40227    [conventional, univariate, multivariate, funct...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8886 words.
# Out of those 4606 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="df3e0278-9be8-4b36-aac3-c4c59eea5f5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df3e0278-9be8-4b36-aac3-c4c59eea5f5f")) {                    Plotly.newPlot(                        "df3e0278-9be8-4b36-aac3-c4c59eea5f5f",                        [{"x":["integrated","probabilistic","graphical","reasoning","framework","treatment","introduction","integrate","principled","inference","subsequent","recommender","relationship","differences","naturally","performance","perception","desirable","important","applications","intelligence","understanding","recognition","potentials","expensive","prediction","segmentation","demonstrates","structured","parameters","necessary","efficiency","estimation","estimators","otherwise","significant","impressive","effectiveness","dimension","usefulness","potential","intersection","exponential","efficient","convolutional","calculation","performing","stochastic","conditional","iteration","undertake","functions","statistical","optimization","initiating","different","simulator","optimizing","derivative","sequences","collection","recommend","collected","decisions","objective","information","metamodel","components","experimental","demonstrate","embedding","structures","outperforms","expressive","embeddings","interchangeable","representations","describes","exploration","synthesizing","randomized","establish","efficiently","computational","optimality","effective","generalize","boltzmann","generalization","algorithm","reinforcement","promising","inefficient","challenge","parameterized","empirical","innovations","maximized","diffusion","influence","propagated","dependent","particular","theoretical","algorithms","providing","justifications","competitive","collectively","typically","candidate","reasonable","maximization","preprocessing","observing","precision","conventional","validated","clearance","experimentally","robustness","successfully","advantages","deployment","manufacturing","recurrent","articulated","technique","exceeding","mechanical","nonlinear","variational","effectively","autoencoder","investigated","experiments","additionally","verification","generative","correctness","developing","distributions","investigation","interesting","unsupervised","developed","probability","magnitude","component","implementation","underlying","independence","frequencies","frequency","equivariant","improvements","implementations","intrinsically","nonadaptive","reduction","dimensionality","convergence","throughput","counterparts","independent","separation","necessitate","fundamental","implement","resulting","approximations","properties","observation","unrealistic","mathematical","classical","increases","dimensional","covariance","simplified","incompatibility","executing","autonomous","respective","respectively","techniques","answering","execution","automated","objectives","attention","conditions","comparison","compilation","replanning","surrogates","compiling","normalized","benchmarks","developers"],"y":[45,169,60,128,575,29,35,36,24,209,25,16,67,44,65,880,43,31,321,405,106,163,356,8,62,221,200,56,100,263,78,161,217,16,24,247,18,207,63,26,155,10,52,397,354,17,93,126,91,44,2,200,162,337,1,722,19,52,4,93,86,3,76,51,160,717,1,116,372,573,118,126,261,29,70,3,223,83,54,14,23,53,160,296,20,233,57,11,89,855,110,114,18,150,14,162,8,4,28,52,14,73,252,145,598,83,9,98,8,113,63,40,33,29,20,78,103,40,2,61,96,92,83,24,11,129,7,256,5,12,65,51,113,27,42,585,59,42,122,17,53,121,27,66,145,191,180,52,99,137,122,26,10,54,3,106,41,7,1,98,54,123,12,13,128,24,2,84,66,153,36,205,71,3,69,101,57,172,32,20,2,7,50,29,80,365,58,29,89,38,150,145,151,9,2,1,4,23,91,9],"type":"bar"},{"x":["integrated","probabilistic","graphical","reasoning","framewo ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4606,), (4606, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8175

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structural</span> <span style=''>Node</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Embeddings</span> <span style=''>Via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Diffusion</span> <span style=''>Wavelets</span> <br/><br/><span style=''>Nodes</span> <span style=''>residing</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>different</span> <span style=''>parts</span> <span style=''>of</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>can</span> <span style=''>have</span> <span style=''>similar</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structural</span> <span style=''>roles</span> <span style=''>within</span> <span style=''>their</span> <span style=''>local</span> <span style=''>network</span> <span style=''>topology</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identification</span> <span style=''>of</span> <span style=''>such</span> <span style=''>roles</span> <span style=''>provides</span> <span style=''>key</span> <span style=''>insight</span> <span style=''>into</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5333333333333333);'>organization</span> <span style=''>of</span> <span style=''>networks</span> <span style=''>and</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>for</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>tasks</span> <span style=''>However</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structural</span> <span style='background-color:rgba(0, 255, 0, 0.3393393393393393);'>representations</span> <span style=''>of</span> <span style=''>nodes</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.4344473007712082);'>challenging</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>it</span> <span style=''>has</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>involved</span> <span style=''>manually</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specifying</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tailoring</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>topological</span> <span style=''>features</span> <span style=''>for</span> <span style=''>each</span> <span style=''>node</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>GraphWave</span> <span style=''>a</span> <span style=''>method</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>represents</span> <span style=''>each</span> <span style=''>nodes</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.32142857142857134);'>neighborhood</span> <span style=''>via</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.37454545454545457);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>leveraging</span> <span style=''>heat</span> <span style=''>wavelet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diffusion</span> <span style=''>patterns</span> <span style=''>Instead</span> <span style=''>of</span> <span style=''>training</span> <span style=''>on</span> <span style=''>hand</span> <span style=''>selected</span> <span style=''>features</span> <span style=''>GraphWave</span> <span style=''>learns</span> <span style=''>these</span> <span style='background-colo ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Robust</span> <span style=''>PCA</span> <span style=''>and</span> <span style=''>subspace</span> <span style=''>tracking</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incomplete</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>using</span> <span style=''>L0</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>surrogates</span> <br/><br/><span style=''>Many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>of</span> <span style=''>a</span> <span style=''>data</span> <span style=''>matrix</span> <span style=''>into</span> <span style=''>a</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>and</span> <span style=''>a</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>Existing</span> <span style=''>methods</span> <span style=''>that</span> <span style=''>tackle</span> <span style=''>this</span> <span style=''>task</span> <span style=''>use</span> <span style=''>the</span> <span style=''>nuclear</span> <span style=''>norm</span> <span style=''>and</span> <span style=''>L1</span> <span style=''>cost</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>as</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relaxations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraint</span> <span style=''>and</span> <span style=''>the</span> <span style=''>sparsity</span> <span style=''>measure</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>respectively</span> <span style=''>or</span> <span style=''>employ</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>thresholding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>that</span> <span style=''>allows</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstructing</span> <span style=''>and</span> <span style=''>tracking</span> <span style=''>a</span> <span style=''>subspace</span> <span style=''>of</span> <span style=''>upper</span> <span style=''>bounded</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incomplete</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corrupted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>It</span> <span style=''>does</span> <span style=''>not</span> <span style=''>require</span> <span style=''>any</span> <span style=''>a</span> <span style=''>priori</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>about</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>outliers</span> <span style=''>The</span> <span style=''>core</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intrinsic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Conjugate</span> <span style=''>Gradient</span> <span style=''>method</span> <span style=''>on</span> <span style=''>the</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3); ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style=''>Robust</span> <span style=''>PCA</span> <span style=''>via</span> <span style=''>Gradient</span> <span style=''>Descent</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>Robust</span> <span style=''>PCA</span> <span style=''>in</span> <span style=''>the</span> <span style=''>fully</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partially</span> <span style=''>observed</span> <span style=''>settings</span> <span style=''>Without</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corruptions</span> <span style=''>this</span> <span style=''>is</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <span style=''>problem</span> <span style=''>From</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.33742331288343563);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>standpoint</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>has</span> <span style=''>been</span> <span style=''>recently</span> <span style=''>well</span> <span style=''>studied</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>on</span> <span style=''>when</span> <span style=''>recovery</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>(how</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3852813852813853);'>observations</span> <span style=''>do</span> <span style=''>we</span> <span style=''>need</span> <span style=''>how</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corruptions</span> <span style=''>can</span> <span style=''>we</span> <span style=''>tolerate)</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>is</span> <span style=''>by</span> <span style=''>now</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understood</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>and</span> <span style=''>analyzes</span> <span style=''>a</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>approach</span> <span style=''>that</span> <span style=''>greatly</span> <span style=''>reduces</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>the</span> <span style=''>above</span> <span style=''>problems</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>the</span> <span style=''>best</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>in</span> <span style=''>the</span> <span style=''>fully</span> <span style=''>observed</span> <span style=''>case</span> <span style=''>with</span> <span style=''>r</span> <span style=''>denoting</span> <span style=''>rank</span> <span style=''>and</span> <span style=''>d</span> <span style='background-color:rgba(255, 0, 0, 0.38536585365853665);'>dimension</span> <span style=''>we</span> <span style=''>reduce</span> <span style=''>the</span> <span style='ba ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Global</span> <span style=''>overview</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Imitation</span> <span style=''>Learning</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Imitation</span> <span style=''>Learning</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style=''>task</span> <span style=''>where</span> <span style=''>the</span> <span style=''>learner</span> <span style=''>tries</span> <span style=''>to</span> <span style=''>mimic</span> <span style=''>an</span> <span style=''>experts</span> <span style=''>action</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>achieve</span> <span style=''>the</span> <span style=''>best</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>Several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>recently</span> <span style=''>for</span> <span style=''>this</span> <span style=''>task</span> <span style=''>In</span> <span style=''>this</span> <span style=''>project</span> <span style=''>we</span> <span style=''>aim</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>proposing</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>review</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presenting</span> <span style=''>their</span> <span style=''>main</span> <span style=''>features</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparing</span> <span style=''>them</span> <span style=''>on</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>and</span> <span style=''>their</span> <span style=''>regret</span> <span style=''>bounds</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.10032362459546926)
# 	knowledge (0.12405609492988134)
# 	experimental (0.133764832793959)
# 	processing (0.10643653362099964)
# 	segmentation (0.0719165767709457)
# 	different (0.259618842143114)
# 	information (0.25782092772384035)
# 	detection (0.12693275800071915)
# 	convolutional (0.1272923408845739)
# 	recognition (0.12801150665228336)
#
# Some Statistics words are:
# 	variational (0.10104011887072809)
# 	variables (0.13967310549777118)
# 	estimation (0.16988608221892026)
# 	stochastic (0.13719663199603765)
# 	theoretical (0.14759782070331848)
# 	distribution (0.1817731550272412)
# 	statistical (0.16196136701337296)
# 	inference (0.19415552253590887)
# 	dimensional (0.18722139673105498)
# 	regression (0.17781079742446756)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="95fa843e-28dc-4f42-8805-c91667d8d31a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95fa843e-28dc-4f42-8805-c91667d8d31a")) {                    Plotly.newPlot(                        "95fa843e-28dc-4f42-8805-c91667d8d31a",                        [{"x":["integrated","probabilistic","graphical","reasoning","framework","treatment","introduction","integrate","principled","inference","subsequent","recommender","relationship","differences","naturally","performance","perception","desirable","important","applications","intelligence","understanding","recognition","potentials","expensive","prediction","segmentation","demonstrates","structured","parameters","necessary","efficiency","estimation","estimators","otherwise","significant","impressive","effectiveness","dimension","usefulness","potential","intersection","exponential","efficient","convolutional","calculation","performing","stochastic","conditional","iteration","undertake","functions","statistical","optimization","initiating","different","simulator","optimizing","derivative","sequences","collection","recommend","collected","decisions","objective","information","metamodel","components","experimental","demonstrate","embedding","structures","outperforms","expressive","embeddings","interchangeable","representations","describes","exploration","synthesizing","randomized","establish","efficiently","computational","optimality","effective","generalize","boltzmann","generalization","algorithm","reinforcement","promising","inefficient","challenge","parameterized","empirical","innovations","maximized","diffusion","influence","propagated","dependent","particular","theoretical","algorithms","providing","justifications","competitive","collectively","typically","candidate","reasonable","maximization","preprocessing","observing","precision","conventional","validated","clearance","experimentally","robustness","successfully","advantages","deployment","manufacturing","recurrent","articulated","technique","exceeding","mechanical","nonlinear","variational","effectively","autoencoder","investigated","experiments","additionally","verification","generative","correctness","developing","distributions","investigation","interesting","unsupervised","developed","probability","magnitude","component","implementation","underlying","independence","frequencies","frequency","equivariant","improvements","implementations","intrinsically","nonadaptive","reduction","dimensionality","convergence","throughput","counterparts","independent","separation","necessitate","fundamental","implement","resulting","approximations","properties","observation","unrealistic","mathematical","classical","increases","dimensional","covariance","simplified","incompatibility","executing","autonomous","respective","respectively","techniques","answering","execution","automated","objectives","attention","conditions","comparison","compilation","replanning","surrogates","compiling","normalized","benchmarks","developers","procedures","benchmark","evaluation","benchmarking","community","strengths","retrieval","organized","researchers","scenarios","successful","launching","limitations","solutions","evaluated","implemented","differentiate","mechanism","development","analyzing","attacking","reflection","processing","prototype","vulnerable","significantly","guarantees","malicious","decreased","detection","especially","characteristics","evaluations","reflected","performed","reflections","leveraged","cooperating","increasingly","authentication","prevalent","accurately","technologies","conceptual","ontologies","addresses","expectations","conducted","representative","conceptualisation","specified","analytically","concentration","highlights","ontolo ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	contrarily
# 	inapplicable
# 	sparsities
# 	kronecker
# 	mentioning
# 	integrable
# 	multiarmed
# 	anonymization
# 	metabolite
# 	jackknife
# 	schizophrenia
# 	inspecting
# 	tightness
# 	monetization
# 	prognostics
# 	disaggregation
# 	integrand
# 	tempering
# 	quadrature
# 	detectability
# Some words which never appear in Statistics papers:
# 	justifications
# 	clearance
# 	articulated
# 	verification
# 	incompatibility
# 	compilation
# 	replanning
# 	compiling
# 	launching
# 	differentiate
# 	reflection
# 	reflections
# 	cooperating
# 	authentication
# 	conceptualisation
# 	ontological
# 	understandable
# 	occlusions
# 	inheritance
# 	histology

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.084896347482725e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7691666666666667
